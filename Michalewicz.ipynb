# %% [markdown]
# # Michalewicz

# %% [markdown]
# Michalewicz is an interesting optimization function. It has a large number of local minima, which can cause algorithms to become trapped in local minima. It can also be defined on any number of dimensions, which makes it an interesting function for high-dimensional optimization problems.
#
# Reference: https://www.sfu.ca/~ssurjano/michal.html

# %% [markdown]
# #### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Function Definition

# %%
lowBound = 0
highBound = np.pi
numDimensions = 2 #Usually 10+, but 2 is better for plotting
trigPower = 10 #"m" in the definition
ranges = []
for i in range(numDimensions):
    ranges.append([-lowBound, highBound])
#Note: global minima values are known for some specific values of trigPower

def michalewicz(x):
    output = 0
    for i in range(len(x)):
        output -= np.sin(x[i]) * (np.sin((i + 1) * (x[i] ** 2) / np.pi)) ** (2 * trigPower)
    return(output)

# %% [markdown]
# ## Plotting

# %%
resolution = 0.01
inputs = []
for x in np.arange(lowBound, highBound, resolution):
    for y in np.arange(lowBound, highBound, resolution):
        inputs.append([x, y])
        
xs = [point[0] for point in inputs]
ys = [point[1] for point in inputs]
cs = [michalewicz(point) for point in inputs]

plt.title("Michalewicz Heatmap")
plt.scatter(xs, ys, c = cs, cmap = "coolwarm") 
plt.colorbar(label = "Michalewicz value")
plt.xlim(lowBound, highBound)
plt.ylim(lowBound, highBound)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()
